# %% [markdown]
# # Study on NYPD Office complaints

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Glossary was looked at to find the different descriptions of the columns/titles in the complaints dataset

# %%
glossary =pd.read_excel(r'D:\Jupyter notebook\Data sets\CCRB-Complaint-Data_202007271729\CCRB Data Layout Table.xlsx',sheet_name=0)
glossary.head(-1) #Get a  overview of the glossary dataset
# Out:
#                   field name  \
# 0              unique_mos_id
# 1                 first_name
# 2                  last_name
# 3                command_now
# 4               complaint_id
# 5             month_received
# 6              year_received
# 7               month_closed
# 8                year_closed
# 9        command_at_incident
# 10      rank_abbrev_incident
# 11           rank_abbrev_now
# 12                  rank_now
# 13             rank_incident
# 14             mos_ethnicity
# 15                mos_gender
# 16          mos_age_incident
# 17     complainant_ethnicity
# 18        complainant_gender
# 19  complainant_age_incident
# 20                 fado_type
# 21                allegation
# 22                  precinct
# 23            contact_reason
# 24       outcome_description
#
#                                           description   glossary
# 0     unique ID of the officer ("member of service")         NaN
# 1                                Officer's first name        NaN
# 2                                 Officer's last name        NaN
# 3        Officer's command assignment as of July 2020  See Tab 3
# 4                          Unique ID of the complaint        NaN
# 5            Month the complaint was received by CCRB        NaN
# 6             Year the complaint was received by CCRB        NaN
# 7   Month the complaint investigation was closed b...        NaN
# 8   Year the complaint investigation was closed by...        NaN
# 9   Officer's command assignment at the time of th...        NaN
# 10  Officer's rank at the time of the incident, ab...  See Tab 2
# 11       Officer's rank as of July 2020, abbreviation  See Tab 2
# 12                     Officer's rank as of July 2020  See Tab 2
# 13         Officer's rank at the time of the incident  See Tab 2
# 14                                Officer's ethnicity        NaN
# 15                                   Officer's gender        NaN
# 16                  Officer's age at time of incident        NaN
# 17                            Complainant's ethnicity        NaN
# 18                               Complainant's gender        NaN
# 19              Complainant's age at time of incident        NaN
# 20                    Top-level category of complaint  See Tab 4
# 21                     Specific category of complaint  See Tab 4
# 22             Precinct associated with the complaint        NaN
# 23       Reason officer made contact with complainant        NaN
# 24  Outcome of the contact between office and comp...        NaN

# %% [markdown]
# In the glossary column, we can see that the excel file has 5 sheets, we'll use these during the data cleaning process

# %% [markdown]
# Based on the glosssary, some data cleaning and feature engineering can be done on the complaints data set for example joining the first and last names to reduce the number of columns, getting rid of id columns e.t.c.

# %%
df = pd.read_csv(r'D:\Jupyter notebook\Data sets\CCRB-Complaint-Data_202007271729\allegations.csv')
df.info() #to get a brief overview of the data we are dealing with
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33358 entries, 0 to 33357
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   unique_mos_id             33358 non-null  int64
#  1   first_name                33358 non-null  object
#  2   last_name                 33358 non-null  object
#  3   command_now               33358 non-null  object
#  4   shield_no                 33358 non-null  int64
#  5   complaint_id              33358 non-null  int64
#  6   month_received            33358 non-null  int64
#  7   year_received             33358 non-null  int64
#  8   month_closed              33358 non-null  int64
#  9   year_closed               33358 non-null  int64
#  10  command_at_incident       31814 non-null  object
#  11  rank_abbrev_incident      33358 non-null  object
#  12  rank_abbrev_now           33358 non-null  object
#  13  rank_now                  33358 non-null  object
#  14  rank_incident             33358 non-null  object
#  15  mos_ethnicity             33358 non-null  object
#  16  mos_gender                33358 non-null  object
#  17  mos_age_incident          33358 non-null  int64
#  18  complainant_ethnicity     28894 non-null  object
#  19  complainant_gender        29163 non-null  object
#  20  complainant_age_incident  28546 non-null  float64
#  21  fado_type                 33358 non-null  object
#  22  allegation                33357 non-null  object
#  23  precinct                  33334 non-null  float64
#  24  contact_reason            33159 non-null  object
#  25  outcome_description       33302 non-null  object
#  26  board_disposition         33358 non-null  object
# dtypes: float64(2), int64(8), object(17)
# memory usage: 6.9+ MB
#    unique_mos_id first_name last_name command_now  shield_no  complaint_id  \
# 0          10004   Jonathan      Ruiz     078 PCT       8409         42835
# 1          10007       John     Sears     078 PCT       5952         24601
# 2          10007       John     Sears     078 PCT       5952         24601
# 3          10007       John     Sears     078 PCT       5952         26146
# 4          10009      Noemi    Sierra     078 PCT      24058         40253
#
#    month_received  year_received  month_closed  year_closed  ...  \
# 0               7           2019             5         2020  ...
# 1              11           2011             8         2012  ...
# 2              11           2011             8         2012  ...
# 3               7           2012             9         2013  ...
# 4               8           2018             2         2019  ...
#
#   mos_age_incident complainant_ethnicity complainant_gender  \
# 0               32                 Black             Female
# 1               24                 Black               Male
# 2               24                 Black               Male
# 3               25                 Black               Male
# 4               39                   NaN                NaN
#
#   complainant_age_incident           fado_type                    allegation  \
# 0                     38.0  Abuse of Authority  Failure to provide RTKA card
# 1                     26.0         Discourtesy                        Action
# 2                     26.0  Offensive Language                          Race
# 3                     45.0  Abuse of Authority                      Question
# 4                     16.0               Force                Physical force
#
#   precinct                                contact_reason  \
# 0     78.0                       Report-domestic dispute
# 1     67.0                              Moving violation
# 2     67.0                              Moving violation
# 3     67.0  PD suspected C/V of violation/crime - street
# 4     67.0                                Report-dispute
#
#                 outcome_description                         board_disposition
# 0  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
# 1   Moving violation summons issued                   Substantiated (Charges)
# 2   Moving violation summons issued                   Substantiated (Charges)
# 3  No arrest made or summons issued                   Substantiated (Charges)
# 4    Arrest - other violation/crime      Substantiated (Command Discipline A)
#
# [5 rows x 27 columns]

# %% [markdown]
# We can see that there a few columns with missing values especially the race and gender columns.The rows with missing values (in the ethnicity  and gender) were deleted since these cannot be guessed with the information we have

# %%
df.complainant_ethnicity.unique()
# Out:
# array(['Black', nan, 'White', 'Asian', 'Refused', 'Hispanic', 'Unknown',
#        'Other Race', 'American Indian'], dtype=object)

# %% [markdown]
# We can see that the refused,unknown, nan,Other Race aren't races so they will be deleted

# %%
Not_races = {'nan':np.nan,'Refused':np.nan,'Unknown':np.nan,'Other Race':np.nan} #creating a list of unknown races to be replaced 
df.complainant_ethnicity = df.complainant_ethnicity.replace(Not_races)
df.dropna(subset=['complainant_ethnicity'],how='any',axis=0,inplace=True)
df.complainant_ethnicity.unique() #checking the races/ethnicities we now have in the dataset
# Out:
# array(['Black', 'White', 'Asian', 'Hispanic', 'American Indian'],
#       dtype=object)

# %% [markdown]
# The first and last names will be joined and the first and last name columns will then be deleted

# %%
df['Name'] = df.first_name + ' ' + df.last_name
df.drop(['first_name','last_name'],axis=1,inplace=True) 
df.Name
# Out:
# 0          Jonathan Ruiz
# 1             John Sears
# 2             John Sears
# 3             John Sears
# 5            Paula Smith
#               ...
# 33353    Tomasz Pulawski
# 33354    Tomasz Pulawski
# 33355    Tomasz Pulawski
# 33356    Tomasz Pulawski
# 33357    Tomasz Pulawski
# Name: Name, Length: 26917, dtype: object

# %% [markdown]
# Getting rid of certain columns such as unique_mos_id, shield_n0,complaint_id  since we already have the officer's name and the description of the offence in fado type and allegation columns

# %%
df.drop(['unique_mos_id','complaint_id','shield_no'],axis=1,inplace=True)
df.shape[1]  #number of rows have reduced from 27 to 23
# Out:
# 23

# %%
#Dealing with command now column
df.command_now.unique()
# Out:
# array(['078 PCT', '079 DET', '010 PCT', '079 PCT', '013 DET', '001 PCT',
#        '081 DET', '081 PCT', '083 DET', '083 PCT', '013 PCT', '084 DET',
#        '084 PCT', '088 DET', '001 DET', '088 PCT', '090 DET', '090 PCT',
#        '094 DET', '094 PCT', '100 PCT', '101 DET', '101 PCT', '102 DET',
#        '102 PCT', '103 DET', '103 PCT', '017 DET', '104 DET', '104 PCT',
#        '017 PCT', '105 DET', '105 PCT', '106 DET', '106 PCT', '107 DET',
#        '107 PCT', '108 DET', '108 PCT', '109 DET', '109 PCT', '110 DET',
#        '110 PCT', '019 DET', '111 DET', '111 PCT', '112 DET', '112 PCT',
#        '019 PCT', '113 DET', '113 PCT', '114 DET', '114 PCT', '115 DET',
#        '115 PCT', '120 DET', '120 PCT', '121 DET', '121 PCT', '122 DET',
#        '122 PCT', '123 DET', '123 PCT', 'A&E', 'AUTO CR', 'AUX P.S',
#        'AV.UNIT', '020 DET', 'BARRIER', 'BK SVS', 'BKLN CT', 'BKROBSQ',
#        '020 PCT', 'BM SEC', 'BOMB SQ', 'BUS UT', 'BX CT', 'BX SVS',
#        'BXROBSQ', 'C A B', 'C C SQD', 'C E D', 'C R C', 'C S O',
#        'C/PRV D', 'C/SCENE', 'CAB COD', 'CD IRS', 'CD OFF', 'CD OP/U',
#        'COL POL', 'COMMDIV', '023 DET', 'CPK PCT', 'CRJ BUR', 'CRM CTL',
#        '023 PCT', 'CT BUR', 'CT LMSI', 'CTERRDV', 'CW T TF', 'D C P I',
#        'D-E T/F', 'DA BKLN', 'DA BX', 'DA NY', 'DA QNS', 'DA SI',
#        'DB BNHM', 'DB BSHM', 'DB BXHM', 'DB CED', 'DB CEIS', 'DB CID',
#        'DB CRD', 'DB FCTF', 'DB FID', 'DB GLD', 'DB GVSD', 'DB HATE',
#        'DB LPS', 'DB MNHM', 'DB MSHM', 'DB QNHM', 'DB SID', 'DB SVD',
#        'DBBKZ10', 'DBBKZ13', 'DBBN', 'DBBN OP', 'DBBS', 'DBBS OP', 'DBBX',
#        'DBBX OP', 'DBCR Z1', 'DBM ZN6', 'DBMN', '024 DET', 'DBMN OP',
#        'DBMS', 'DBQN OP', 'DBQS', 'DBQS OP', 'DBSI', 'DBSI OP', '024 PCT',
#        'DC EEO', 'DC LABR', 'DCEI', 'DCER', 'DET BUR', 'DIS CTL',
#        'DPT INV', 'E S U', '005 DET', 'EM OPS', 'EQP SEC', 'ESS 01',
#        'ESS 02', 'ESS 03', 'ESS 04', 'ESS 05', 'ESS 06', 'ESS 07',
#        'ESS 08', 'ESS 09', 'ESS 10', 'ESU CAN', 'F S S', 'F.T.S.',
#        'FAM SEC', 'FLT SVC', 'FM DIV', 'FM SEC', 'FORCEID', 'GANG BN',
#        'GANG BS', 'GANG BX', 'GANG MN', '005 PCT', 'GANG QN', 'GANG QS',
#        'GANG SI', 'GVSD Z1', '025 DET', 'GVSD Z2', 'H BKLYN', 'H BX/Q',
#        'H MAN', '025 PCT', 'H&WELL', 'HARBOR', 'HBK RT', 'HBM RT',
#        'HBXQ RT', 'HOSS', 'HOU', 'HQ SEC', 'HSG BUR', 'HWY 01', 'HWY 02',
#        'HWY 03', 'HWY 05', 'HWY CIS', 'HWY DST', 'I T B', 'I T S D',
#        'I.A.B.', 'INT BUR', 'INT CIS', '026 DET', 'INT EPU', '026 PCT',
#        'INT OAS', 'INT PSS', 'INT UOU', 'INV SUP', 'JB/R/TF', 'JT T/F',
#        'JUV CRM', 'L S S D', 'L.I.M.S', 'LDS TRN', 'LEG BUR', 'LIC DIV',
#        'M E L D', 'M SVS', 'MAN CT', 'MB SSZN', 'MC/SQD', 'MED DIV',
#        '028 DET', '028 PCT', 'MNROBSQ', 'MOUNTED', 'MP SQD', 'MTN DET',
#        'MTN PCT', 'MTS DET', 'MTS PCT', 'NARCBBN', 'NARCBBS', 'NARCBBX',
#        'NARCBMN', 'NARCBMS', 'NARCBQN', 'NARCBQS', 'NARCBSI', 'OMAP',
#        'P C C U', 'P C O', 'P S B', 'PA UPTU', '030 DET', 'PB CAD',
#        '030 PCT', 'PB ERS', 'PB HRD', 'PB SAS', 'PBBN', 'PBBN SU', 'PBBS',
#        'PBBS SU', 'PBBX', 'PBBX SU', 'PBMN', 'PBMN SU', 'PBMS', 'PBMS SU',
#        'PBQ/N', 'PBQ/S', 'PBQN SU', '032 DET', 'PBQS SU', 'PBSI',
#        '032 PCT', 'PER BUR', 'POL ACD', 'POL LAB', 'PROPCLK', 'PSA 1',
#        'PSA 2', 'PSA 3', 'PSA 4', 'PSA 5', 'PSA 6', 'PSA 7', '033 DET',
#        'PSA 8', '033 PCT', 'PSA 9', 'Q SVS', 'QB SSZN', 'QM SEC',
#        'QNROBSQ', 'QNS CT', 'REC TNG', '034 DET', '034 PCT', 'RM BUR',
#        'RMB QAD', 'RTCC', 'S S B', 'S T D', 'S.I. CT', 'SP FRDS',
#        'SPL TRN', 'SRG', 'SRG 1', 'SRG 2', 'SRG 3', 'SRG 4', 'SRG 5',
#        'SS DIV', 'STR FOR', 'SVD Z1', 'SVD Z2', 'SVD Z3', 'T.A.R.U',
#        'TAXI UT', 'TB', 'TB ATU', 'TB CAN', 'TB DT01', '040 DET',
#        'TB DT02', 'TB DT03', '040 PCT', 'TB DT04', 'TB DT11', 'TB DT12',
#        'TB DT20', 'TB DT23', 'TB DT30', 'TB DT32', 'TB DT33', 'TB DT34',
#        'TB LIAS', 'TB M/TF', 'TB MANH', 'TB SOD', 'TB VTF', 'TRB TED',
#        'TRN BUR', 'TRP BUR', 'VED MCS', 'VED ZN1', 'VED ZN2', 'VICE',
#        'WARRSEC', 'WTC CMD', 'YTH SD', '041 DET', '041 PCT', '006 PCT',
#        '042 DET', '042 PCT', '043 DET', '043 PCT', '044 DET', '044 PCT',
#        '045 DET', '045 PCT', '046 DET', '046 PCT', '007 DET', '047 DET',
#        '047 PCT', '007 PCT', '048 DET', '048 PCT', '049 DET', '049 PCT',
#        '050 DET', '050 PCT', '052 DET', '052 PCT', '060 DET', '060 PCT',
#        '009 DET', '061 DET', '061 PCT', '062 DET', '009 PCT', '062 PCT',
#        '063 DET', '063 PCT', '066 DET', '066 PCT', '067 DET', '067 PCT',
#        '068 DET', '068 PCT', '069 DET', '069 PCT', '070 DET', '070 PCT',
#        '071 DET', '071 PCT', '010 DET', '072 DET', '072 PCT', '073 DET',
#        '073 PCT', '075 DET', '075 PCT', '076 PCT', '077 DET', '077 PCT'],
#       dtype=object)

# %% [markdown]
# The commands of the officers are abbreviated hence had to comprehend.
# According to the sheet 1 of the glossary, sheet3 (Tab 3) has more information about the command of the officer which was imported below.

# %%
s3 = pd.read_excel(r'D:\Jupyter notebook\Data sets\CCRB-Complaint-Data_202007271729\CCRB Data Layout Table.xlsx',sheet_name=2)
s3.head(5)
# Out:
#   Abbreviation               Command Name
# 0        C R C  Critical Response Command
# 1      WARRSEC            Warrant Section
# 2      075 PCT               075 Precinct
# 3       I.A.B.    Internal Affairs Bureau
# 4      046 PCT               046 Precinct

# %%
#The command abbreviations are going to be swapped with the command full names for easy understanding
abbrev_dict = dict(zip(s3.Abbreviation,s3['Command Name'])) #making a dicitonary with abbreviations and command Names
df.command_now = df.command_now.map(abbrev_dict)  # changes abbreviations to full names
df.command_at_incident = df.command_at_incident.map(abbrev_dict)
df.command_now.unique() #to show us the changes we've made
# Out:
# array(['078 Precinct', '079 Detective Squad', '010 Precinct',
#        '079 Precinct', '013 Detective Squad', '001 Precinct',
#        '081 Detective Squad', '081 Precinct', '083 Detective Squad',
#        '083 Precinct', '013 Precinct', '084 Detective Squad',
#        '084 Precinct', '088 Detective Squad', '001 Detective Squad',
#        '088 Precinct', '090 Detective Squad', '090 Precinct',
#        '094 Detective Squad', '094 Precinct', '100 Precinct',
#        '101 Detective Squad', '101 Precinct', '102 Detective Squad',
#        '102 Precinct', '103 Detective Squad', '103 Precinct',
#        '017 Detective Squad', '104 Detective Squad', '104 Precinct',
#        '005 Precinct', '105 Detective Squad', '105 Precinct',
#        '106 Detective Squad', '106 Precinct', '107 Detective Squad',
#        '025 Precinct', '108 Detective Squad', '108 Precinct',
#        '109 Detective Squad', '107 Precinct', '110 Detective Squad',
#        '110 Precinct', '019 Detective Squad', '111 Detective Squad',
#        '111 Precinct', '112 Detective Squad', '112 Precinct',
#        '019 Precinct', '113 Detective Squad', '113 Precinct',
#        '114 Detective Squad', '114 Precinct', '115 Detective Squad',
#        '115 Precinct', '120 Detective Squad', '120 Precinct',
#        '121 Detective Squad', '121 Precinct', '122 Detective Squad',
#        '122 Precinct', '123 Detective Squad', '123 Precinct',
#        'Arson and Explosion Squad', 'Auto Crime Division',
#        'Auxiliary Police Section', 'Aviation Unit', '020 Detective Squad',
#        'Barrier Section',
#        'Detective Bureau Brooklyn Special Victims Squad',
#        'Brooklyn Court Section', 'Brooklyn Robbery Squad', '020 Precinct',
#        'Building Maintenance Section', 'Bomb Squad', 'Bus Unit',
#        'Bronx Court Section', 'BX SVS', 'Bronx Robbery Squad',
#        'Community Affairs Bureau', 'C C SQD',
#        'Career Development Division', 'Critical Response Command', nan,
#        'Crime Prevention Division', 'Crime Scene Unit', 'CAB COD',
#        'Chief of Department Investigation Review Section',
#        'Chief of Department Office',
#        'Chief of Department Operations Unit', 'Communications Division',
#        '023 Detective Squad', 'Central Park Precinct',
#        'Criminal Justice Bureau', '023 Precinct',
#        'Counterterrorism Bureau',
#        'Counterterrorism Lower Manhattan Security Initiative',
#        'Counterterrorism Division',
#        'Transportation Bureau Citywide Traffic',
#        'Deputy Commissioner of Public Information',
#        'Drug Enforcement Task Force', 'DA BKLN', 'DA BX', 'DA NY',
#        'DA QNS', 'DA SI',
#        'Detective Borough Brooklyn North Homicide Squad',
#        'Detective Borough Brooklyn South Homicide Squad',
#        'Detective Borough Bronx Homicide Squad',
#        'Organized Crime Investigation Division',
#        'Central Investigation and Research Division',
#        'Detective Bureau Central Robbery Division',
#        'Detective Bureau Financial Crimes Task Force',
#        'Forensics Investigations Division',
#        'Detective Bureau Grand Larceny Division',
#        'Gun Violence Suppression Division',
#        'Detective Bureau Hate Crimes Task Force',
#        'Detective Bureau Latent Print Section',
#        'Detective Bureau Manhattan North Homicide Squad',
#        'Detective Bureau Manhattan South Homicide Squad',
#        'Detective Bureau Queens Homicide Squad', 'DB SID',
#        'Detective Bureau Special Victims Division',
#        'Detective Borough Brooklyn Zone 10',
#        'Detective Borough Brooklyn Zone 13',
#        'Detective Borough Brooklyn North',
#        'Detective Borough Brooklyn North Operations',
#        'Detective Borough Brooklyn South',
#        'Detective Borough Brooklyn Operations', 'Detective Borough Bronx',
#        'DBCR Z1', 'Detective Borough Manhattan Zone 6',
#        'Detective Borough Manhattan North', '024 Detective Squad',
#        'Detective Borough Manhattan North Operations',
#        'Detective Borough Manhattan South',
#        'Detective Borough Queens South',
#        'Detective Borough Queens South Operations',
#        'Detective Borough Staten Island', '024 Precinct',
#        'Deputy Commissioner Equal Employment Opportunity',
#        'Deputy Commissioner Labor Relations', 'Detective Bureau',
#        'Disorder Control Unit', 'Department of Investigation Squad',
#        'Emergency Service Unit', '005 Detective Squad',
#        'Emergency Operations Center', 'Equipment Section',
#        'Emergency Service Squad 01', 'Emergency Service Squad 02',
#        'Emergency Service Squad 03', 'Emergency Service Squad 04',
#        'Emergency Service Squad 05', 'Emergency Service Squad 06',
#        'Emergency Service Squad 07', 'Emergency Service Squad 08',
#        'Emergency Service Squad 09', 'Emergency Service Squad 10',
#        'Emergency Service Unit Canine Team',
#        'Firearms Suppression Division', 'Firearms and Tactics Section',
#        'Fleet Services Division', 'Facilities Management Division',
#        'Force Investigation Division', 'Gang Squad Brooklyn North',
#        'Gang Squad Brooklyn South', 'Gang Squad Bronx',
#        'Gang Squad Manhattan North', '017 Precinct',
#        'Gang Squad Queens North', 'Gang Squad Queens South',
#        'Gang Squad Staten Island',
#        'Gun Violence Suppression Division Zone 01', '025 Detective Squad',
#        'Gun Violence Suppression Division Zone 02', 'Housing Brooklyn',
#        'Housing Bronx/Queens', 'Housing Manhattan', '109 Precinct',
#        'Harbor Unit', 'Headquarters Security', 'Housing Bureau',
#        'Highway Unit 01', 'Highway Unit 02', 'Highway Unit 03',
#        'Highway Unit 05', 'Transportation Bureau Highway District',
#        'Office of Information Technology', 'I T S D',
#        'Internal Affairs Bureau', 'Intelligence Bureau',
#        'Criminal Intelligence Section', '026 Detective Squad', 'INT EPU',
#        '026 Precinct', 'Intelligence Operations and Analysis Section',
#        'Intelligence Public Security Section', 'INT UOU',
#        'Investigative Support Division', 'Joint Bank Robbery Task Force',
#        'Joint Terrorism Task Force', 'Juvenile Crime Section',
#        'Life Safety Systems Division',
#        'Leave Integrity Management Section',
#        'Leadership Training Section', 'Legal Bureau', 'License Division',
#        'Military and Extended Leave Desk',
#        'Detective Bureau Manhattan Special Victims Squad',
#        'Manhattan Court Section', 'MB SSZN', 'Major Case Squad',
#        'Medical Division', '028 Detective Squad', '028 Precinct',
#        'Manhattan Robbery Squad', 'Mounted Unit', 'Missing Person Squad',
#        'Midtown North Detective Squad', 'Midtown North Precinct',
#        'Midtown South Detective Squad', 'Midtown South Precinct',
#        'Narcotics Borough Brooklyn North',
#        'Narcotics Borough Brooklyn South', 'Narcotics Borough Bronx',
#        'Narcotics Borough Manhattan North',
#        'Narcotics Borough Manhattan South',
#        'Narcotics Borough Queens North', 'Narcotics Borough Queens South',
#        'Narcotics Borough Staten Island', 'OMAP',
#        'Police Cadet Corps Unit', 'Police Commissioner Office',
#        'Patrol Services Bureau', 'Uniformed Promotions Training Unit',
#        '030 Detective Squad', '030 Precinct',
#        'Patrol Borough Brooklyn North',
#        'Patrol Borough Brooklyn North Specialized Units',
#        'Patrol Borough Brooklyn South',
#        'Patrol Borough Brooklyn South Specialized Units',
#        'Patrol Borough Bronx', 'Patrol Borough Bronx Specialized Units',
#        'Patrol Borough Manhattan North',
#        'Patrol Borough Manhattan North Specialized Units',
#        'Patrol Borough Manhattan South',
#        'Patrol Borough Manhattan South Specialized Units',
#        'Patrol Borough Queens North', 'Patrol Borough Queens South',
#        'Patrol Borough Queens North Specialized Units',
#        '032 Detective Squad',
#        'Patrol Borough Queens South Specialized Units',
#        'Patrol Borough Staten Island', '032 Precinct', 'Personnel Bureau',
#        'Police Academy Payroll and Roll Call', 'Police Laboratory',
#        'Property Clerk Division', 'Police Service Area 1',
#        'Police Service Area 2', 'Police Service Area 3',
#        'Police Service Area 4', 'Police Service Area 5',
#        'Police Service Area 6', 'Police Service Area 7',
#        '033 Detective Squad', 'Police Service Area 8', '033 Precinct',
#        'Police Service Area 9', 'Queens Special Victims Squad',
#        'School Safety Queens Brooklyn Staten Island Zone',
#        'Quartermaster Section', 'Queens Robbery Squad',
#        'Queens Court Section', 'Recruit Training Section',
#        '034 Detective Squad', '034 Precinct', 'Risk Management Bureau',
#        'RMB QAD', 'Real Time Crime Center', 'Support Services Bureau',
#        'S T D', 'Staten Island Court Section', 'Special Fraud Squad',
#        'Specialized Training Section', 'SRG',
#        'Strategic Response Group 1', 'Strategic Response Group 2',
#        'Strategic Response Group 3', '060 Precinct',
#        'Strategic Response Group 5', 'School Safety Division',
#        'Organized Crime Drug Enforcement Strike Force', 'SVD Z1',
#        'Bronx Special Victims Squad', 'SVD Z3',
#        'Technical Assistance and Response Unit', 'Taxi Unit',
#        'Transit Bureau', 'Transit Bureau Anti-Terrorism Unit',
#        'Transit Bureau Canine Unit', 'Transit Bureau District 1',
#        '040 Detective Squad', 'Transit Bureau District 2',
#        'Transit Bureau District 33', '040 Precinct', '009 Precinct',
#        'Transit Bureau District 11', 'Transit Bureau District 12',
#        'Transit Bureau District 3', 'Transit Bureau District 23',
#        'Transit Bureau District 30', 'Transit Bureau District 32',
#        'Transit Bureau District 20', 'Transit Bureau District 34',
#        'Transit Authority Liaison', 'Transit Bureau Manhattan Task Force',
#        'Transit Borough Manhattan',
#        'Transit Bureau Special Operations District',
#        'Transit Bureau Citywide Vandals Task Force',
#        'Transportation Bureau Traffic Enforcement District',
#        'Transportation Bureau', 'VICE Enforcement', 'Warrant Section',
#        'World Trade Center Command', '041 Detective Squad',
#        '041 Precinct', '006 Precinct', '042 Detective Squad',
#        '042 Precinct', '043 Detective Squad', '043 Precinct',
#        '044 Detective Squad', '044 Precinct', '045 Detective Squad',
#        '045 Precinct', '046 Detective Squad', '046 Precinct',
#        '007 Detective Squad', '047 Detective Squad', '047 Precinct',
#        '007 Precinct', '048 Detective Squad', '048 Precinct',
#        '049 Detective Squad', '049 Precinct', '050 Detective Squad',
#        '050 Precinct', '052 Detective Squad', '052 Precinct',
#        '060 Detective Squad', 'Strategic Response Group 4',
#        '009 Detective Squad', '061 Detective Squad', '062 Precinct',
#        '062 Detective Squad', 'Transit Bureau District 4', '061 Precinct',
#        '063 Detective Squad', '063 Precinct', '066 Detective Squad',
#        '066 Precinct', '067 Detective Squad', '067 Precinct',
#        '068 Detective Squad', '068 Precinct', '069 Detective Squad',
#        '069 Precinct', '070 Detective Squad', '077 Precinct',
#        '071 Detective Squad', '071 Precinct', '010 Detective Squad',
#        '072 Detective Squad', '072 Precinct', '073 Detective Squad',
#        '073 Precinct', '075 Detective Squad', '075 Precinct',
#        '076 Precinct', '077 Detective Squad', '070 Precinct'],
#       dtype=object)

# %% [markdown]
# Looking at the rank_abbrev column in the glossary and df datasets, we are reffered to sheet2 for more information

# %%
#Sheet 2(Tab 2) is imported to have a bried overview of the rank_abbrev information
s2 = pd.read_excel(r'D:\Jupyter notebook\Data sets\CCRB-Complaint-Data_202007271729\CCRB Data Layout Table.xlsx',sheet_name=1)
s2.head(5)
# Out:
#   Abbreviation                               Rank
# 0          POM                     Police Officer
# 1          POF                     Police Officer
# 2           PO                     Police Officer
# 3          PSA  Police Officer Special Assignment
# 4          SGT                           Sergeant

# %% [markdown]
# Based on sheet2 the rank_abbrev column provides more information of the type of rank of the police officer. For Simplicity, we can get rid of the rank abbreviated columns

# %%
df.drop(['rank_abbrev_now','rank_abbrev_incident'],axis=1,inplace=True)
df.info() #wwe're now down to 21 columns from 27 columns
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26917 entries, 0 to 33357
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   command_now               26138 non-null  object
#  1   month_received            26917 non-null  int64
#  2   year_received             26917 non-null  int64
#  3   month_closed              26917 non-null  int64
#  4   year_closed               26917 non-null  int64
#  5   command_at_incident       25485 non-null  object
#  6   rank_now                  26917 non-null  object
#  7   rank_incident             26917 non-null  object
#  8   mos_ethnicity             26917 non-null  object
#  9   mos_gender                26917 non-null  object
#  10  mos_age_incident          26917 non-null  int64
#  11  complainant_ethnicity     26917 non-null  object
#  12  complainant_gender        26899 non-null  object
#  13  complainant_age_incident  26574 non-null  float64
#  14  fado_type                 26917 non-null  object
#  15  allegation                26917 non-null  object
#  16  precinct                  26903 non-null  float64
#  17  contact_reason            26788 non-null  object
#  18  outcome_description       26884 non-null  object
#  19  board_disposition         26917 non-null  object
#  20  Name                      26917 non-null  object
# dtypes: float64(2), int64(5), object(14)
# memory usage: 4.5+ MB
#     command_now  month_received  year_received  month_closed  year_closed  \
# 0  078 Precinct               7           2019             5         2020
# 1  078 Precinct              11           2011             8         2012
# 2  078 Precinct              11           2011             8         2012
# 3  078 Precinct               7           2012             9         2013
# 5  078 Precinct               5           2017            10         2017
#
#              command_at_incident        rank_now   rank_incident  \
# 0                   078 Precinct  Police Officer  Police Officer
# 1  Patrol Borough Brooklyn South  Police Officer  Police Officer
# 2  Patrol Borough Brooklyn South  Police Officer  Police Officer
# 3  Patrol Borough Brooklyn South  Police Officer  Police Officer
# 5                   078 Precinct        Sergeant        Sergeant
#
#   mos_ethnicity mos_gender  ...  complainant_ethnicity complainant_gender  \
# 0      Hispanic          M  ...                  Black             Female
# 1         White          M  ...                  Black               Male
# 2         White          M  ...                  Black               Male
# 3         White          M  ...                  Black               Male
# 5         Black          F  ...                  White               Male
#
#   complainant_age_incident           fado_type  \
# 0                     38.0  Abuse of Authority
# 1                     26.0         Discourtesy
# 2                     26.0  Offensive Language
# 3                     45.0  Abuse of Authority
# 5                     31.0  Abuse of Authority
#
#                               allegation precinct  \
# 0           Failure to provide RTKA card     78.0
# 1                                 Action     67.0
# 2                                   Race     67.0
# 3                               Question     67.0
# 5  Refusal to process civilian complaint     78.0
#
#                                  contact_reason  \
# 0                       Report-domestic dispute
# 1                              Moving violation
# 2                              Moving violation
# 3  PD suspected C/V of violation/crime - street
# 5                            C/V telephoned PCT
#
#                 outcome_description                         board_disposition  \
# 0  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
# 1   Moving violation summons issued                   Substantiated (Charges)
# 2   Moving violation summons issued                   Substantiated (Charges)
# 3  No arrest made or summons issued                   Substantiated (Charges)
# 5  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
#
#             Name
# 0  Jonathan Ruiz
# 1     John Sears
# 2     John Sears
# 3     John Sears
# 5    Paula Smith
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### There still a few columns with missing values.Were going to start with the command_now and command_at_incident columns. We'll replace the command now empty columns with the command_at_incident values and delete any missing command_at_incident cells

# %%
df.command_now = df.command_now.fillna(value=df.command_at_incident)
df.dropna(subset=['command_at_incident'],how='any',axis=0,inplace=True)

# %% [markdown]
# #### The complainant_age_incident column will be filled by the mean age in the dataset

# %%
df.complainant_age_incident.fillna(value=np.mean(df.complainant_age_incident),inplace=True)

# %% [markdown]
# #### The complainant_gender column's missing cells will be replaced by the commonest gender

# %%
df.complainant_gender.unique() #checking the different genders
# Out:
# array(['Female', 'Male', 'Transman (FTM)', 'Not described', nan,
#        'Transwoman (MTF)', 'Gender non-conforming'], dtype=object)

# %%
#We need to replace the Not described and nan genders with the most common gender
df.complainant_gender.value_counts()
# Out:
# Male                     21012
# Female                    4423
# Transwoman (MTF)            17
# Not described               12
# Gender non-conforming        2
# Transman (FTM)               2
# Name: complainant_gender, dtype: int64

# %%
missing_genders = {np.nan:'Male','Not described':'Male'}
df.complainant_gender.replace(missing_genders,inplace=True)
df.complainant_gender.unique()
# Out:
# array(['Female', 'Male', 'Transman (FTM)', 'Transwoman (MTF)',
#        'Gender non-conforming'], dtype=object)

# %% [markdown]
# #### The columns contact_reason  and precinct's missing cell values will be deleted since its tricky to assume the contact reason and the precinct

# %%
df.dropna(subset=['precinct','contact_reason'],axis=0,how='any',inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25384 entries, 0 to 33357
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   command_now               25384 non-null  object
#  1   month_received            25384 non-null  int64
#  2   year_received             25384 non-null  int64
#  3   month_closed              25384 non-null  int64
#  4   year_closed               25384 non-null  int64
#  5   command_at_incident       25384 non-null  object
#  6   rank_now                  25384 non-null  object
#  7   rank_incident             25384 non-null  object
#  8   mos_ethnicity             25384 non-null  object
#  9   mos_gender                25384 non-null  object
#  10  mos_age_incident          25384 non-null  int64
#  11  complainant_ethnicity     25384 non-null  object
#  12  complainant_gender        25384 non-null  object
#  13  complainant_age_incident  25384 non-null  float64
#  14  fado_type                 25384 non-null  object
#  15  allegation                25384 non-null  object
#  16  precinct                  25384 non-null  float64
#  17  contact_reason            25384 non-null  object
#  18  outcome_description       25355 non-null  object
#  19  board_disposition         25384 non-null  object
#  20  Name                      25384 non-null  object
# dtypes: float64(2), int64(5), object(14)
# memory usage: 4.3+ MB

# %% [markdown]
# #### Finally,  the outcome description column will be looked at in more detail where the commonest outcome will be used to fill the missing value cells in the column

# %%
df.outcome_description.unique()
df. outcome_description.value_counts()
# Out:
# No arrest made or summons issued        9119
# Arrest - other violation/crime          7951
# Summons - disorderly conduct            1791
# Summons - other violation/crime         1588
# Arrest - resisting arrest               1335
# Arrest - disorderly conduct              866
# Arrest - assault (against a PO)          714
# Moving violation summons issued          709
# Arrest - OGA                             559
# Other VTL violation summons issued       450
# Parking summons issued                   225
# Juvenile Report                           37
# Arrest - harrassment (against a PO)        6
# Summons - harrassment (against a PO)       4
# Summons - OGA                              1
# Name: outcome_description, dtype: int64

# %%
df.outcome_description.fillna(value='No arrest made or summons issued',inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25384 entries, 0 to 33357
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   command_now               25384 non-null  object
#  1   month_received            25384 non-null  int64
#  2   year_received             25384 non-null  int64
#  3   month_closed              25384 non-null  int64
#  4   year_closed               25384 non-null  int64
#  5   command_at_incident       25384 non-null  object
#  6   rank_now                  25384 non-null  object
#  7   rank_incident             25384 non-null  object
#  8   mos_ethnicity             25384 non-null  object
#  9   mos_gender                25384 non-null  object
#  10  mos_age_incident          25384 non-null  int64
#  11  complainant_ethnicity     25384 non-null  object
#  12  complainant_gender        25384 non-null  object
#  13  complainant_age_incident  25384 non-null  float64
#  14  fado_type                 25384 non-null  object
#  15  allegation                25384 non-null  object
#  16  precinct                  25384 non-null  float64
#  17  contact_reason            25384 non-null  object
#  18  outcome_description       25384 non-null  object
#  19  board_disposition         25384 non-null  object
#  20  Name                      25384 non-null  object
# dtypes: float64(2), int64(5), object(14)
# memory usage: 4.3+ MB

# %% [markdown]
# ## The last step of the data cleaning process is to check each column to see if there are any unique values that represent missing such as 'None', 'unspecified' etcetra

# %%
df.command_now.unique()
# Out:
# array(['078 Precinct', '079 Detective Squad', '010 Precinct',
#        '079 Precinct', '013 Detective Squad', '001 Precinct',
#        '081 Detective Squad', '081 Precinct', '083 Detective Squad',
#        '083 Precinct', '084 Detective Squad', '084 Precinct',
#        '013 Precinct', '088 Detective Squad', '001 Detective Squad',
#        '088 Precinct', '090 Detective Squad', '090 Precinct',
#        '094 Detective Squad', '094 Precinct', '100 Precinct',
#        '101 Detective Squad', '101 Precinct', '102 Detective Squad',
#        '102 Precinct', '103 Detective Squad', '103 Precinct',
#        '017 Detective Squad', '104 Detective Squad', '104 Precinct',
#        '005 Precinct', '105 Detective Squad', '105 Precinct',
#        '106 Detective Squad', '106 Precinct', '107 Detective Squad',
#        '025 Precinct', '108 Detective Squad', '108 Precinct',
#        '109 Detective Squad', '107 Precinct', '110 Detective Squad',
#        '110 Precinct', '019 Detective Squad', '111 Detective Squad',
#        '111 Precinct', '112 Detective Squad', '112 Precinct',
#        '019 Precinct', '113 Detective Squad', '113 Precinct',
#        '114 Detective Squad', '114 Precinct', '115 Detective Squad',
#        '115 Precinct', '120 Detective Squad', '120 Precinct',
#        '121 Detective Squad', '121 Precinct', '122 Detective Squad',
#        '122 Precinct', '123 Detective Squad', '123 Precinct',
#        'Arson and Explosion Squad', 'Auto Crime Division',
#        'Auxiliary Police Section', 'Aviation Unit', '020 Detective Squad',
#        'Barrier Section',
#        'Detective Bureau Brooklyn Special Victims Squad',
#        'Brooklyn Court Section', 'Brooklyn Robbery Squad', '020 Precinct',
#        'Building Maintenance Section', 'Bomb Squad', 'Bus Unit',
#        'Bronx Court Section', 'BX SVS', 'Bronx Robbery Squad', 'C C SQD',
#        'Career Development Division', 'Critical Response Command',
#        '077 Precinct', '067 Precinct', 'Transit Bureau', '068 Precinct',
#        'Crime Prevention Division', 'Crime Scene Unit', 'CAB COD',
#        'Chief of Department Investigation Review Section',
#        'Chief of Department Office',
#        'Chief of Department Operations Unit', '032 Precinct',
#        'Narcotics Borough Manhattan North', 'Communications Division',
#        '023 Detective Squad', 'Central Park Precinct',
#        'Criminal Justice Bureau', 'Transit Bureau District 4',
#        '050 Precinct', 'Patrol Borough Queens South', '062 Precinct',
#        '075 Precinct', '023 Precinct', 'Narcotics Borough Bronx',
#        'Narcotics Borough Manhattan South',
#        'Narcotics Borough Brooklyn South',
#        'Narcotics Borough Brooklyn North', 'Midtown South Precinct',
#        '048 Precinct', 'Counterterrorism Bureau',
#        'Counterterrorism Lower Manhattan Security Initiative',
#        'Counterterrorism Division',
#        'Transportation Bureau Citywide Traffic',
#        'Deputy Commissioner of Public Information',
#        'Drug Enforcement Task Force', 'DA BKLN', 'DA BX', 'DA NY',
#        'DA QNS', 'DA SI',
#        'Detective Borough Brooklyn North Homicide Squad',
#        'Detective Borough Brooklyn South Homicide Squad',
#        'Detective Borough Bronx Homicide Squad', 'Patrol Borough Bronx',
#        '109 Precinct', '043 Precinct', '040 Precinct', '044 Precinct',
#        '046 Precinct', '041 Precinct', '006 Precinct', 'Warrant Section',
#        '034 Precinct', 'Organized Crime Investigation Division',
#        'Central Investigation and Research Division',
#        'Detective Bureau Central Robbery Division',
#        'Detective Bureau Financial Crimes Task Force',
#        'Forensics Investigations Division',
#        'Detective Bureau Grand Larceny Division',
#        'Gun Violence Suppression Division',
#        'Detective Bureau Hate Crimes Task Force',
#        'Detective Bureau Latent Print Section',
#        'Detective Bureau Manhattan North Homicide Squad',
#        'Detective Bureau Manhattan South Homicide Squad',
#        'Detective Bureau Queens Homicide Squad', 'DB SID',
#        'Detective Bureau Special Victims Division',
#        'Detective Borough Brooklyn Zone 10',
#        'Detective Borough Brooklyn Zone 13',
#        'Detective Borough Brooklyn North',
#        'Detective Borough Brooklyn North Operations',
#        'Detective Borough Brooklyn South',
#        'Detective Borough Brooklyn Operations', 'Detective Borough Bronx',
#        'DBCR Z1', 'Detective Borough Manhattan Zone 6',
#        'Detective Borough Manhattan North', '024 Detective Squad',
#        'Detective Borough Manhattan North Operations',
#        'Detective Borough Manhattan South', 'Police Service Area 4',
#        'Detective Borough Queens South',
#        'Detective Borough Queens South Operations',
#        'Detective Borough Staten Island', '024 Precinct',
#        'Deputy Commissioner Equal Employment Opportunity',
#        'Deputy Commissioner Labor Relations',
#        'Housing Special Operations Section',
#        'Patrol Borough Brooklyn North Specialized Units',
#        'Detective Bureau', 'Disorder Control Unit',
#        'Department of Investigation Squad', 'Emergency Service Unit',
#        '005 Detective Squad', 'Emergency Operations Center',
#        'Equipment Section', 'Emergency Service Squad 01',
#        'Emergency Service Squad 02', 'Emergency Service Squad 03',
#        'Emergency Service Squad 04', 'Emergency Service Squad 05',
#        'Emergency Service Squad 06', 'Emergency Service Squad 07',
#        'Emergency Service Squad 08', 'Emergency Service Squad 09',
#        'Emergency Service Squad 10', 'Emergency Service Unit Canine Team',
#        'Firearms Suppression Division', 'Firearms and Tactics Section',
#        'Fleet Services Division', 'Facilities Management Division',
#        '061 Precinct', 'License Division', 'Force Investigation Division',
#        'Gang Squad Brooklyn North', 'Gang Squad Brooklyn South',
#        'Gang Squad Bronx', 'Gang Squad Manhattan North', '017 Precinct',
#        'Gang Squad Queens North', 'Gang Squad Queens South',
#        'Gang Squad Staten Island',
#        'Gun Violence Suppression Division Zone 01', '025 Detective Squad',
#        'Gun Violence Suppression Division Zone 02', 'Housing Brooklyn',
#        'Housing Bronx/Queens', 'Housing Manhattan', 'Medical Division',
#        'Patrol Borough Staten Island', 'Harbor Unit',
#        'Housing Borough Brooklyn Impact Response Team', '073 Precinct',
#        'Housing Borough Manhattan Impact Response Team', '049 Precinct',
#        'Police Service Area 7', 'Police Service Area 5', '070 Precinct',
#        'Intelligence Operations and Analysis Section',
#        'Criminal Intelligence Section', '071 Precinct',
#        'Narcotics Borough Queens North', '030 Precinct',
#        'Transit Bureau District 33', '009 Precinct',
#        'Headquarters Security', 'Housing Bureau', 'Highway Unit 01',
#        'Highway Unit 02', 'Highway Unit 03', 'Highway Unit 05',
#        'Patrol Borough Brooklyn North', '063 Precinct',
#        'Transportation Bureau Highway District',
#        'Office of Information Technology', 'I T S D',
#        'Internal Affairs Bureau', 'Intelligence Bureau',
#        '026 Detective Squad', 'INT EPU', '026 Precinct',
#        'Intelligence Public Security Section', 'INT UOU',
#        'Investigative Support Division', 'Joint Bank Robbery Task Force',
#        'Joint Terrorism Task Force', 'Juvenile Crime Section',
#        'Life Safety Systems Division',
#        'Leave Integrity Management Section',
#        'Leadership Training Section', 'Legal Bureau',
#        'Military and Extended Leave Desk',
#        'Detective Bureau Manhattan Special Victims Squad',
#        'Manhattan Court Section', 'MB SSZN', 'Major Case Squad',
#        '028 Detective Squad', '028 Precinct', 'Manhattan Robbery Squad',
#        'Mounted Unit', 'Missing Person Squad',
#        'Midtown North Detective Squad', 'Midtown North Precinct',
#        'Midtown South Detective Squad', 'Narcotics Borough Queens South',
#        'Narcotics Borough Staten Island', 'OMAP',
#        'Police Cadet Corps Unit', 'Police Commissioner Office',
#        'Patrol Services Bureau', 'Uniformed Promotions Training Unit',
#        '030 Detective Squad', '069 Precinct',
#        'Patrol Borough Manhattan South', 'Police Service Area 6',
#        'Transit Bureau Borough Brooklyn Task Force',
#        'Police Service Area 1', '052 Precinct',
#        'Transit Bureau District 12', 'Patrol Borough Brooklyn South',
#        'Patrol Borough Brooklyn South Specialized Units',
#        'Patrol Borough Bronx Specialized Units',
#        'Patrol Borough Manhattan North',
#        'Patrol Borough Manhattan North Specialized Units',
#        'Patrol Borough Manhattan South Specialized Units',
#        'Patrol Borough Queens North',
#        'Patrol Borough Queens North Specialized Units',
#        '032 Detective Squad',
#        'Patrol Borough Queens South Specialized Units',
#        'Personnel Bureau', 'Police Academy Payroll and Roll Call',
#        'Police Laboratory', 'Property Clerk Division',
#        'Police Service Area 2', 'Police Service Area 3',
#        '033 Detective Squad', 'Police Service Area 8', '033 Precinct',
#        'Police Service Area 9', 'Queens Special Victims Squad',
#        'School Safety Queens Brooklyn Staten Island Zone',
#        'Quartermaster Section', 'Queens Robbery Squad',
#        'Queens Court Section', 'Recruit Training Section',
#        '034 Detective Squad', 'Risk Management Bureau', 'RMB QAD',
#        'Real Time Crime Center', 'S T D', 'Staten Island Court Section',
#        'Special Fraud Squad', 'Specialized Training Section', 'SRG',
#        'Strategic Response Group 1', 'Strategic Response Group 2',
#        'Strategic Response Group 3', '060 Precinct',
#        'Strategic Response Group 5', 'School Safety Division',
#        'Organized Crime Drug Enforcement Strike Force', 'SVD Z1',
#        'Bronx Special Victims Squad', 'SVD Z3',
#        'Technical Assistance and Response Unit', 'Taxi Unit',
#        'Transit Bureau Anti-Terrorism Unit', 'Transit Bureau Canine Unit',
#        'Transit Bureau District 1', '040 Detective Squad',
#        'Transit Bureau District 2', 'Transit Bureau District 11',
#        'Transit Bureau District 3', 'Transit Bureau District 23',
#        'Transit Bureau District 30', 'Transit Bureau District 32',
#        'Transit Bureau District 20', 'Transit Bureau District 34',
#        'Transit Authority Liaison', 'Transit Bureau Manhattan Task Force',
#        'Transit Borough Manhattan',
#        'Transit Bureau Special Operations District',
#        'Transit Bureau Citywide Vandals Task Force',
#        'Transportation Bureau Traffic Enforcement District',
#        'Transportation Bureau', 'VICE Enforcement',
#        'World Trade Center Command', '072 Precinct',
#        '041 Detective Squad', '042 Detective Squad', '042 Precinct',
#        '043 Detective Squad', '044 Detective Squad',
#        '045 Detective Squad', '045 Precinct', '046 Detective Squad',
#        '007 Detective Squad', '047 Detective Squad', '047 Precinct',
#        '007 Precinct', '048 Detective Squad', '049 Detective Squad',
#        '050 Detective Squad', '052 Detective Squad',
#        '060 Detective Squad', 'Strategic Response Group 4',
#        '009 Detective Squad', '061 Detective Squad',
#        '062 Detective Squad', '063 Detective Squad',
#        '066 Detective Squad', '066 Precinct', '067 Detective Squad',
#        '068 Detective Squad', '069 Detective Squad',
#        '070 Detective Squad', '071 Detective Squad',
#        '010 Detective Squad', '072 Detective Squad',
#        '073 Detective Squad', '075 Detective Squad', '076 Precinct',
#        '077 Detective Squad'], dtype=object)

# %%
df.month_received.unique()
# Out:
# array([ 7, 11,  5,  8,  3, 10,  4, 12,  1,  9,  6,  2], dtype=int64)

# %%
df.year_received.unique()
# Out:
# array([2019, 2011, 2012, 2017, 2015, 2018, 2016, 2013, 2014, 2010, 2001,
#        2002, 2007, 2003, 2006, 2008, 2009, 2005, 2004, 2000, 1999, 1998,
#        2020], dtype=int64)

# %%
df.month_closed.unique()
# Out:
# array([ 5,  8,  9, 10,  2, 11,  7,  1, 12,  4,  3,  6], dtype=int64)

# %%
df.year_closed.unique()
# Out:
# array([2020, 2012, 2013, 2017, 2016, 2018, 2019, 2014, 2015, 2011, 2002,
#        2003, 2009, 2004, 2008, 2010, 2006, 2007, 2005, 2001, 2000],
#       dtype=int64)

# %%
df.command_at_incident.unique()
# Out:
# array(['078 Precinct', 'Patrol Borough Brooklyn South', '079 Precinct',
#        '067 Precinct', 'Patrol Borough Brooklyn South Specialized Units',
#        'Patrol Borough Brooklyn North Specialized Units',
#        '073 Detective Squad', 'Police Service Area 2',
#        'Police Service Area 3', 'Narcotics Borough Brooklyn North',
#        '079 Detective Squad', '010 Precinct', '109 Precinct',
#        '110 Precinct', '083 Precinct', 'Transit Bureau District 4',
#        '028 Precinct', '120 Precinct', '001 Precinct', '072 Precinct',
#        '077 Precinct', 'Narcotics Borough Staten Island',
#        'Patrol Borough Queens South', '101 Precinct', '100 Precinct',
#        '090 Precinct', 'Police Service Area 4', '013 Detective Squad',
#        '073 Precinct', '071 Precinct', '007 Precinct',
#        'Patrol Borough Brooklyn North', 'Police Service Area 5',
#        '115 Precinct', '023 Precinct', '075 Precinct', '112 Precinct',
#        '013 Precinct', '081 Precinct', 'Gang Squad Brooklyn North',
#        '069 Precinct', '088 Precinct', 'Police Service Area 6',
#        '094 Precinct', '063 Precinct', '076 Precinct',
#        'Narcotics Borough Brooklyn South', '070 Precinct',
#        '083 Detective Squad', 'Strategic Response Group 4',
#        '047 Precinct', '061 Precinct', '042 Precinct',
#        'Patrol Borough Queens North', 'Narcotics Borough Queens North',
#        '113 Precinct', '084 Precinct', 'Narcotics Division',
#        'Narcotics Borough Manhattan North', 'Housing Bronx/Queens',
#        '088 Detective Squad', 'Midtown South Precinct', '107 Precinct',
#        '090 Detective Squad', '103 Precinct', '025 Precinct',
#        '094 Detective Squad', 'Police Service Area 7',
#        'Detective Bureau Grand Larceny Division', '050 Precinct',
#        '045 Precinct', 'Midtown North Precinct',
#        'Strategic Response Group 3', 'School Safety Division',
#        '114 Precinct', '046 Precinct', '102 Detective Squad',
#        '102 Precinct', '104 Precinct', '106 Precinct',
#        'Patrol Borough Manhattan North', '105 Detective Squad',
#        '105 Precinct', 'Narcotics Borough Queens South',
#        'Patrol Borough Bronx', '005 Precinct',
#        'Police Commissioner Office',
#        'Housing Borough Brooklyn Impact Response Team',
#        'Uniformed Promotions Training Unit',
#        'Patrol Borough Queens South Specialized Units', '034 Precinct',
#        '040 Precinct', '048 Precinct', '107 Detective Squad',
#        '108 Precinct', '044 Precinct', '041 Precinct',
#        'Housing Special Operations Section', '019 Precinct',
#        '043 Precinct', 'Internal Affairs Bureau', '068 Precinct',
#        '109 Detective Squad', '111 Precinct', '032 Precinct',
#        'Transit Bureau District 33',
#        'Transit Bureau Borough Brooklyn Task Force',
#        'Organized Crime Control Bureau', 'Police Service Area 1',
#        'Narcotics Borough Bronx', '030 Precinct', '033 Precinct',
#        'Highway Unit 03', '049 Precinct', '020 Precinct',
#        'Police Service Area 9', 'Patrol Borough Manhattan South',
#        '062 Precinct', 'Warrant Section', '120 Detective Squad',
#        '122 Precinct', 'Narcotics Borough Manhattan South',
#        '006 Precinct', 'Military and Extended Leave Desk',
#        '123 Detective Squad', '121 Precinct', 'Gang Squad Staten Island',
#        '063 Detective Squad', 'Transit Bureau District 20',
#        'Gang Squad Brooklyn South', 'Patrol Borough Staten Island',
#        '066 Precinct', '122 Detective Squad', '123 Precinct',
#        'Brooklyn Robbery Squad', '024 Precinct',
#        'Detective Bureau Brooklyn Special Victims Squad',
#        'Brooklyn Court Section', '020 Detective Squad',
#        '043 Detective Squad', 'Transit Bureau District 30',
#        'Transit Bureau', '026 Precinct', 'Bronx Court Section',
#        'Housing Borough Manhattan Impact Response Team',
#        'Patrol Borough Queens North Specialized Units', 'C C SQD',
#        'Juvenile Crime Section', 'Transit Bureau Manhattan Task Force',
#        'Police Service Area 8', 'Gang Squad Bronx',
#        'Critical Response Command', 'Transit Bureau District 2',
#        'Emergency Service Squad 09', '034 Detective Squad',
#        'Central Park Precinct', 'Strategic Response Group 1',
#        'Joint Terrorism Task Force',
#        'Transportation Bureau Citywide Traffic', 'SRG',
#        'Criminal Intelligence Section', 'Drug Enforcement Task Force',
#        '052 Precinct', '017 Precinct', 'Transit Bureau District 34',
#        '081 Detective Squad', '042 Detective Squad',
#        'Detective Borough Bronx Homicide Squad', '047 Detective Squad',
#        '040 Detective Squad', '041 Detective Squad',
#        'Manhattan Court Section', 'Gang Squad Queens South',
#        'Organized Crime Investigation Division', '045 Detective Squad',
#        'Detective Bureau Financial Crimes Task Force',
#        '052 Detective Squad',
#        'Patrol Borough Staten Island Specialized Units',
#        'Patrol Borough Manhattan North Specialized Units',
#        'Detective Bureau Hate Crimes Task Force', '077 Detective Squad',
#        '032 Detective Squad', 'Detective Bureau Special Victims Division',
#        '009 Precinct', 'Detective Borough Manhattan North Operations',
#        'Highway Unit 01', 'Detective Borough Manhattan Zone 2',
#        'Detective Borough Queens South Operations', '113 Detective Squad',
#        'Emergency Service Unit', 'Emergency Service Squad 05',
#        '030 Detective Squad', 'Emergency Service Squad 03',
#        'Emergency Service Squad 08', 'Emergency Service Squad 02',
#        'Emergency Service Squad 06', 'Emergency Service Squad 07',
#        'Emergency Service Squad 04', 'Emergency Service Unit Canine Team',
#        'Strategic Response Group 2', 'Midtown South Detective Squad',
#        'Firearms and Tactics Section', 'License Division',
#        'Gang Squad Manhattan North', 'Gang Squad Queens North',
#        '100 Detective Squad', 'Gun Violence Suppression Division Zone 01',
#        'Gun Violence Suppression Division Zone 02',
#        'Patrol Borough Bronx Specialized Units', '048 Detective Squad',
#        'Transit Bureau District 1', 'Medical Division', 'Highway Unit 05',
#        'Highway Unit 02', 'Intelligence Operations and Analysis Section',
#        'Headquarters Security', 'Leadership Training Section',
#        'Transportation Bureau Highway District',
#        'Recruit Training Section', 'Transit Bureau District 12',
#        'Transit Bureau District 3',
#        'Patrol Bureau Employee Management Division',
#        '006 Detective Squad', '026 Detective Squad',
#        'World Trade Center Command', 'INT EPU', '007 Detective Squad',
#        'INT UOU', '114 Detective Squad', '046 Detective Squad',
#        '028 Detective Squad', '010 Detective Squad', 'Major Case Squad',
#        'Midtown North Detective Squad',
#        'Patrol Borough Manhattan South Specialized Units', 'OMAP',
#        'Applicant Processing Division',
#        'Deputy Commissioner of Public Information',
#        'Police Academy Payroll and Roll Call',
#        'Queens Special Victims Squad',
#        'School Safety Queens Brooklyn Staten Island Zone',
#        'Queens Robbery Squad', 'Queens Court Section',
#        'Special Fraud Squad', 'Strategic Response Group 5',
#        'Technical Assistance and Response Unit',
#        'Transit Bureau Anti-Terrorism Unit', 'Transit Bureau Canine Unit',
#        'Transit Bureau Crime Analysis', 'Transit Bureau District 11',
#        'Transit Bureau District 23', 'Transit Bureau District 32',
#        'Bus Unit', 'Transit Bureau Special Operations District',
#        'Emergency Service Squad 01', '050 Detective Squad',
#        '060 Precinct', '067 Detective Squad', '070 Detective Squad',
#        '075 Detective Squad'], dtype=object)

# %%
df.rank_now.unique()
# Out:
# array(['Police Officer', 'Sergeant', 'Detective', 'Lieutenant',
#        'Deputy Inspector', 'Captain', 'Inspector',
#        'Chiefs and other ranks'], dtype=object)

# %%
df.rank_incident.unique()
# Out:
# array(['Police Officer', 'Sergeant', 'Detective', 'Lieutenant', 'Captain',
#        'Deputy Inspector', 'Inspector'], dtype=object)

# %%
df.mos_ethnicity.unique()
# Out:
# array(['Hispanic', 'White', 'Black', 'Asian', 'American Indian'],
#       dtype=object)

# %%
df.mos_gender.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %% [markdown]
# The gender column will be changed from M and F to Male and Female

# %%
gender = {'M':'Male','F':'Female'}
df.mos_gender.replace(gender,inplace=True)
df.mos_gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.mos_age_incident.unique()
# Out:
# array([32, 24, 25, 50, 43, 34, 35, 30, 27, 28, 29, 33, 31, 36, 37, 38, 40,
#        41, 45, 26, 39, 44, 22, 48, 53, 49, 51, 46, 23, 42, 47, 58, 21, 55,
#        52, 56, 54, 60, 57], dtype=int64)

# %% [markdown]
# complainant_ethnicity and complainant_gender column have already been checked

# %%
df.complainant_age_incident.unique()
# Out:
# array([ 38.        ,  26.        ,  45.        ,  31.        ,
#         34.        ,  60.        ,  39.        ,  30.        ,
#         35.        ,  42.        ,  46.        ,  23.        ,
#         29.        ,  28.        ,  22.        ,  33.        ,
#         17.        ,  15.        ,  50.        ,  27.        ,
#         24.        ,  32.83881736,  43.        ,  37.        ,
#         25.        ,  19.        ,  47.        ,  20.        ,
#         49.        ,  36.        ,  53.        ,  44.        ,
#         55.        ,  18.        ,  16.        ,  21.        ,
#         41.        ,  32.        ,  52.        ,  51.        ,
#         40.        ,  58.        ,  57.        ,  48.        ,
#         13.        ,  65.        ,  77.        ,  63.        ,
#         10.        ,  14.        ,  56.        ,  54.        ,
#         68.        ,  62.        ,  73.        ,  11.        ,
#         59.        ,  74.        ,  61.        ,  64.        ,
#         80.        ,  90.        ,  70.        ,  75.        ,
#         67.        ,  12.        ,  72.        ,   8.        ,
#          0.        ,  71.        ,  69.        ,  76.        ,
#         -1.        ,  81.        ,  66.        ,  87.        ,
#        101.        ,  78.        ,  88.        ,  83.        ,
#         79.        ,  84.        ,   6.        ,   9.        ,
#         86.        ])

# %% [markdown]
# ##### The complainant_age_incident column has ages such as -1 and zero. We can assume zero would mean a baby that is less than a year old.
# ##### The -1 will be changed to the mean age of the complainants

# %%
neg_age = {-1:np.mean(df.complainant_age_incident)}
df.complainant_age_incident.replace(neg_age,inplace=True)
df.complainant_age_incident.unique()
# Out:
# array([ 38.        ,  26.        ,  45.        ,  31.        ,
#         34.        ,  60.        ,  39.        ,  30.        ,
#         35.        ,  42.        ,  46.        ,  23.        ,
#         29.        ,  28.        ,  22.        ,  33.        ,
#         17.        ,  15.        ,  50.        ,  27.        ,
#         24.        ,  32.83881736,  43.        ,  37.        ,
#         25.        ,  19.        ,  47.        ,  20.        ,
#         49.        ,  36.        ,  53.        ,  44.        ,
#         55.        ,  18.        ,  16.        ,  21.        ,
#         41.        ,  32.        ,  52.        ,  51.        ,
#         40.        ,  58.        ,  57.        ,  48.        ,
#         13.        ,  65.        ,  77.        ,  63.        ,
#         10.        ,  14.        ,  56.        ,  54.        ,
#         68.        ,  62.        ,  73.        ,  11.        ,
#         59.        ,  74.        ,  61.        ,  64.        ,
#         80.        ,  90.        ,  70.        ,  75.        ,
#         67.        ,  12.        ,  72.        ,   8.        ,
#          0.        ,  71.        ,  69.        ,  76.        ,
#         32.82438017,  81.        ,  66.        ,  87.        ,
#        101.        ,  78.        ,  88.        ,  83.        ,
#         79.        ,  84.        ,   6.        ,   9.        ,
#         86.        ])

# %%
df.fado_type.unique()
# Out:
# array(['Abuse of Authority', 'Discourtesy', 'Offensive Language', 'Force'],
#       dtype=object)

# %%
df.allegation.unique()
# Out:
# array(['Failure to provide RTKA card', 'Action', 'Race', 'Question',
#        'Refusal to process civilian complaint', 'Sexual orientation',
#        'Word', 'Refusal to provide shield number', 'Retaliatory summons',
#        'Search (of person)', 'Pepper spray', 'Physical force',
#        'Handcuffs too tight', 'Frisk', 'Vehicle stop', 'Vehicle search',
#        'Refusal to provide name/shield number', 'Strip-searched',
#        'Threat of arrest', 'Threat of force (verbal or physical)', 'Stop',
#        'Refusal to obtain medical treatment',
#        'Hit against inanimate object', 'Frisk and/or search', 'Other',
#        'Question and/or stop', 'Nonlethal restraining device',
#        'Retaliatory arrest', 'Chokehold', 'Gender',
#        'Nightstick as club (incl asp & baton)', 'Refusal to provide name',
#        'Seizure of property', 'Gun Pointed',
#        'Other blunt instrument as a club',
#        'Refusal to show search warrant',
#        'Threat to damage/seize property', 'Gesture',
#        'Sex Miscon (Sexual Harassment, Verbal)',
#        'Sex Miscon (Sexual Harassment, Gesture)',
#        'Forcible Removal to Hospital', 'Entry of Premises', 'Ethnicity',
#        'Threat of summons', 'Interference with recording',
#        'Threat re: removal to hospital', 'Property damaged', 'Vehicle',
#        'Photography/Videography', 'Gun Drawn', 'Demeanor/tone',
#        'Restricted Breathing', 'Body Cavity Searches',
#        'Flashlight as club', 'Electronic device information deletion',
#        'Search of recording device', 'Gun as club', 'Religion',
#        'Sexual Misconduct (Sexual Humiliation)', 'Gun fired',
#        'Gun pointed/gun drawn', 'Radio as club',
#        'Improper dissemination of medical info', 'Search of Premises',
#        'Physical disability', 'Failed to Obtain Language Interpretation',
#        'Premises entered and/or searched', 'Police shield', 'Gun pointed',
#        'Refusal to show arrest warrant',
#        'Sex Miscon (Sexual/Romantic Proposition)', 'Animal',
#        'Threat to notify ACS', 'Threat of Arrest',
#        'Questioned immigration status', 'Gender Identity'], dtype=object)

# %%
df.precinct.unique()
# Out:
# array([  78.,   67.,   79.,   77.,   81.,   73.,   90.,   75.,  120.,
#          10.,   25.,  110.,   83.,    9.,   28.,    1.,   68.,   70.,
#          72.,  122.,  113.,  101.,  100.,    7.,   13.,   71.,   23.,
#         112.,   69.,   32.,   94.,   63.,   76.,   47.,   62.,   42.,
#         115.,  109.,   84.,    5.,   88.,   14.,  103.,  107.,  104.,
#          40.,  108.,   50.,   45.,   18.,  102.,  114.,   46.,  106.,
#         105.,   17.,   60.,   34.,   44.,   48.,   41.,   43.,   19.,
#          52.,  111.,   26.,   30.,   33.,   49.,   20.,   61.,    6.,
#         123.,  121.,   66.,   24.,   22., 1000.])

# %%
df.contact_reason.unique()
# Out:
# array(['Report-domestic dispute', 'Moving violation',
#        'PD suspected C/V of violation/crime - street',
#        'C/V telephoned PCT', 'Regulatory inspection', 'Other',
#        'Other violation of VTL', 'Parking violation',
#        'Execution of search warrant',
#        'PD suspected C/V of violation/crime - bldg',
#        'Execution of arrest/bench warrant', 'Report-dispute',
#        'PD suspected C/V of violation/crime - auto',
#        'Report-possession/sale of narcotics',
#        'C/V intervened on behalf of/observed encounter w/3rd party',
#        'Traffic accident', 'Aided case', 'EDP aided case',
#        'C/V at PCT to file complaint of crime', 'Report of other crime',
#        'Report-noise/disturbance', 'PD auto checkpoint',
#        'C/V requested investigation of crime',
#        'C/V at PCT to obtain information', 'CV already in custody',
#        'Report-gun possession/shots fired',
#        'C/V requested info from officer',
#        'PD suspected C/V of violation/crime - subway',
#        'Demonstration/protest', 'Others',
#        'C/V at PCT to retrieve property', 'Assist ACS or other agency',
#        'Patrol Encounter', 'Parade/special event', 'EDP Aided Cases',
#        'PD telephones CV', 'Traffic Incidents/Accident/Prk Violation',
#        'Stop/Question/Frisk', 'Transit checkpoint', 'Arrest/Complainant',
#        'Report of Disturbance/Noise Complaint', 'No contact'],
#       dtype=object)

# %%
df.outcome_description.unique()
# Out:
# array(['No arrest made or summons issued',
#        'Moving violation summons issued',
#        'Summons - other violation/crime', 'Arrest - OGA',
#        'Arrest - other violation/crime',
#        'Other VTL violation summons issued', 'Arrest - resisting arrest',
#        'Arrest - disorderly conduct', 'Summons - disorderly conduct',
#        'Arrest - assault (against a PO)', 'Parking summons issued',
#        'Juvenile Report', 'Arrest - harrassment (against a PO)',
#        'Summons - OGA', 'Summons - harrassment (against a PO)'],
#       dtype=object)

# %%
df.board_disposition.unique()
# Out:
# array(['Substantiated (Command Lvl Instructions)',
#        'Substantiated (Charges)', 'Substantiated (Formalized Training)',
#        'Unsubstantiated', 'Substantiated (Command Discipline A)',
#        'Exonerated', 'Substantiated (Command Discipline B)',
#        'Substantiated (Instructions)',
#        'Substantiated (Command Discipline)',
#        'Substantiated (No Recommendations)'], dtype=object)

# %%
df.Name.unique()
# Out:
# array(['Jonathan Ruiz', 'John Sears', 'Paula Smith', ..., 'Novaidul Neon',
#        'Hassan Paris', 'Tomasz Pulawski'], dtype=object)

# %%
#We'll check the allegations tab/sheet from the glossary for any valuable information
s4 =pd.read_excel(r'D:\Jupyter notebook\Data sets\CCRB-Complaint-Data_202007271729\CCRB Data Layout Table.xlsx',sheet_name=3)
s4.info()
s4.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FADO Category     118 non-null    object
#  1   Allegation type   118 non-null    object
#  2   Count of records  118 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 2.9+ KB
#         FADO Category Allegation type  Count of records
# 0  Offensive Language           Black                56
# 1  Offensive Language       Ethnicity                84
# 2  Offensive Language          Gender               115

# %%
s4.groupby(by='FADO Category').head(15)
# Out:
#           FADO Category                        Allegation type  \
# 0    Offensive Language                                  Black
# 1    Offensive Language                              Ethnicity
# 2    Offensive Language                                 Gender
# 3    Offensive Language                        Gender Identity
# 4    Offensive Language                               Hispanic
# 5    Offensive Language                                 Jewish
# 6    Offensive Language                               Oriental
# 7    Offensive Language                                  Other
# 8    Offensive Language                    Other - Ethnic Slur
# 9    Offensive Language                            Other Asian
# 10   Offensive Language                    Physical disability
# 11   Offensive Language                                   Race
# 12   Offensive Language                               Religion
# 13   Offensive Language                     Sexual orientation
# 14   Offensive Language                                  White
# 15          Discourtesy                                   Word
# 16          Discourtesy                                 Action
# 17          Discourtesy                                  Curse
# 18          Discourtesy                            Nasty Words
# 19          Discourtesy                                Gesture
# 20          Discourtesy                          Demeanor/tone
# 21          Discourtesy                     Other- Discourtesy
# 22          Discourtesy                                  Other
# 23          Discourtesy                           Rude Gesture
# 24          Discourtesy                        Profane Gesture
# 25          Discourtesy                       Gay/Lesbian Slur
# 26          Discourtesy                          Sexist Remark
# 27   Abuse of Authority                                   Stop
# 28   Abuse of Authority                     Search (of person)
# 29   Abuse of Authority                                  Frisk
# 30   Abuse of Authority       Premises entered and/or searched
# 31   Abuse of Authority  Refusal to provide name/shield number
# 32   Abuse of Authority                         Vehicle search
# 33   Abuse of Authority                       Threat of arrest
# 34   Abuse of Authority                           Vehicle stop
# 35   Abuse of Authority   Threat of force (verbal or physical)
# 36   Abuse of Authority                   Question and/or stop
# 37   Abuse of Authority                         Strip-searched
# 38   Abuse of Authority                               Question
# 39   Abuse of Authority                                  Other
# 40   Abuse of Authority                       Property damaged
# 41   Abuse of Authority                    Retaliatory summons
# 88                Force                         Physical force
# 89                Force                            Gun Pointed
# 90                Force                           Pepper spray
# 91                Force  Nightstick as club (incl asp & baton)
# 92                Force                              Chokehold
# 93                Force                             Push/Shove
# 94                Force           Hit against inanimate object
# 95                Force                          Other - Force
# 96                Force                                  Other
# 97                Force                             Punch/Kick
# 98                Force           Nonlethal restraining device
# 99                Force                    Handcuffs too tight
# 100               Force                         Dragged/Pulled
# 101               Force                                   Beat
# 102               Force       Other blunt instrument as a club
#
#      Count of records
# 0                  56
# 1                  84
# 2                 115
# 3                   4
# 4                   9
# 5                   2
# 6                   1
# 7                  48
# 8                  11
# 9                   1
# 10                 15
# 11                307
# 12                 14
# 13                 78
# 14                  8
# 15               3942
# 16                316
# 17                202
# 18                 88
# 19                 51
# 20                 38
# 21                 18
# 22                  8
# 23                  7
# 24                  3
# 25                  3
# 26                  1
# 27               2300
# 28               2047
# 29               1926
# 30               1555
# 31               1483
# 32               1405
# 33               1370
# 34               1094
# 35                912
# 36                696
# 37                556
# 38                527
# 39                461
# 40                359
# 41                291
# 88               4849
# 89                628
# 90                324
# 91                260
# 92                244
# 93                178
# 94                176
# 95                134
# 96                124
# 97                114
# 98                 87
# 99                 76
# 100                63
# 101                57
# 102                49

# %%
#The tab only shows the counts and types of offences
#We'll also check the tab explaining the outcome_description column values
s5 =pd.read_excel(r'D:\Jupyter notebook\Data sets\CCRB-Complaint-Data_202007271729\CCRB Data Layout Table.xlsx',sheet_name=4)
s5.info()
s5.head(-1).T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Disposition  3 non-null      object
#  1   Description  3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes
#                                                              0  \
# Disposition                                      Substantiated
# Description  The alleged conduct occurred and it violated t...
#
#                                                              1
# Disposition                                         Exonerated
# Description  The alleged conduct occurred but did not viola...

# %%
df.to_excel(r'D:\Jupyter notebook\Data sets\CCRB-Complaint-Data_202007271729\Cleaned_NYPD_dataset.xlsx',index=False)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25384 entries, 0 to 33357
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   command_now               25384 non-null  object
#  1   month_received            25384 non-null  int64
#  2   year_received             25384 non-null  int64
#  3   month_closed              25384 non-null  int64
#  4   year_closed               25384 non-null  int64
#  5   command_at_incident       25384 non-null  object
#  6   rank_now                  25384 non-null  object
#  7   rank_incident             25384 non-null  object
#  8   mos_ethnicity             25384 non-null  object
#  9   mos_gender                25384 non-null  object
#  10  mos_age_incident          25384 non-null  int64
#  11  complainant_ethnicity     25384 non-null  object
#  12  complainant_gender        25384 non-null  object
#  13  complainant_age_incident  25384 non-null  float64
#  14  fado_type                 25384 non-null  object
#  15  allegation                25384 non-null  object
#  16  precinct                  25384 non-null  float64
#  17  contact_reason            25384 non-null  object
#  18  outcome_description       25384 non-null  object
#  19  board_disposition         25384 non-null  object
#  20  Name                      25384 non-null  object
# dtypes: float64(2), int64(5), object(14)
# memory usage: 4.3+ MB
#     command_now  month_received  year_received  month_closed  year_closed  \
# 0  078 Precinct               7           2019             5         2020
# 1  078 Precinct              11           2011             8         2012
# 2  078 Precinct              11           2011             8         2012
# 3  078 Precinct               7           2012             9         2013
# 5  078 Precinct               5           2017            10         2017
#
#              command_at_incident        rank_now   rank_incident  \
# 0                   078 Precinct  Police Officer  Police Officer
# 1  Patrol Borough Brooklyn South  Police Officer  Police Officer
# 2  Patrol Borough Brooklyn South  Police Officer  Police Officer
# 3  Patrol Borough Brooklyn South  Police Officer  Police Officer
# 5                   078 Precinct        Sergeant        Sergeant
#
#   mos_ethnicity mos_gender  ...  complainant_ethnicity complainant_gender  \
# 0      Hispanic       Male  ...                  Black             Female
# 1         White       Male  ...                  Black               Male
# 2         White       Male  ...                  Black               Male
# 3         White       Male  ...                  Black               Male
# 5         Black     Female  ...                  White               Male
#
#   complainant_age_incident           fado_type  \
# 0                     38.0  Abuse of Authority
# 1                     26.0         Discourtesy
# 2                     26.0  Offensive Language
# 3                     45.0  Abuse of Authority
# 5                     31.0  Abuse of Authority
#
#                               allegation precinct  \
# 0           Failure to provide RTKA card     78.0
# 1                                 Action     67.0
# 2                                   Race     67.0
# 3                               Question     67.0
# 5  Refusal to process civilian complaint     78.0
#
#                                  contact_reason  \
# 0                       Report-domestic dispute
# 1                              Moving violation
# 2                              Moving violation
# 3  PD suspected C/V of violation/crime - street
# 5                            C/V telephoned PCT
#
#                 outcome_description                         board_disposition  \
# 0  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
# 1   Moving violation summons issued                   Substantiated (Charges)
# 2   Moving violation summons issued                   Substantiated (Charges)
# 3  No arrest made or summons issued                   Substantiated (Charges)
# 5  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
#
#             Name
# 0  Jonathan Ruiz
# 1     John Sears
# 2     John Sears
# 3     John Sears
# 5    Paula Smith
#
# [5 rows x 21 columns]

# %% [markdown]
# # The data cleaning process has been finished, The next notebook will have the data exploratory process
